# %% [markdown]
# # time

# %%
import time
t=time.time()

# %%
start_time=time.time()
print('djd')
end_time=time.time()
over_time=start_time-end_time
over_time
# Out:
# djd
# 0.0

# %%
for i in range(4):
    print('main')
    time.sleep(3)
# Out:
# main
# main
# main
# main

# %%
now=time.time()
now
# Out:
# 1731384989.890341

# %%
now_=round(now,2)
now_
# Out:
# 1731384989.89
