# %% [markdown]
# # time

# %%
import time
t=time.time()

# %%
start_time=time.time()
print('djd')
end_time=time.time()
over_time=start_time-end_time
over_time
# Out:
# djd
# 0.0

# %%
for i in range(4):
    print('main')
    time.sleep(3)
# Out:
# main
# main
# main
# main

# %%
now=time.time()
now
# Out:
# 1732175333.586625

# %%
now_=round(now,2)
now_
# Out:
# 1732175333.59

# %% [markdown]
# # datetime 获取日期

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2024, 11, 21, 15, 48, 53, 635573)

# %% [markdown]
# ## 对于unix纪元
# 可以转换为日期格式，它表示unix开始过了所传入时间之后是什么日期

# %%
datetime.datetime.fromtimestamp(1000000000)
# Out:
# datetime.datetime(2001, 9, 9, 9, 46, 40)

# %%
dt=datetime.datetime.now()
dt.month
# Out:
# 11

# %%
import threading

# %%
print("start program")
def take_a_nap():
    time.sleep(2)
    print("wake up")

thread=threading.Thread(target=take_a_nap)
thread.start()
print("end program")
# Out:
# start program
# end program

# %% [markdown]
# # 从python中打开其它程序

# %%
import subprocess
sbp=subprocess.Popen('D:\WeChat\WeChat.exe')
sbp.poll()==None
sbp.wait()
# Out:
# 0
