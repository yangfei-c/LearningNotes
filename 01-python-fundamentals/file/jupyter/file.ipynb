# %% [markdown]
# # 读取文件

# %% [markdown]
# ## os.path.join
# windows与linux，os x上面文件路径格式是不一样的
# 编写python就要考虑到
# 好在有os.path.join这个工具

# %%
import os

# %%
os.path.join('user','bin')# \\用来转义
# Out:
# 'user\\bin'

# %%
files=['do.text','m.exe','1.jpg']
rootpath='c:\\user'
for file in files:
    filepath=os.path.join(rootpath,file)
    print(filepath)
# Out:
# c:\user\do.text
# c:\user\m.exe
# c:\user\1.jpg

# %% [markdown]
# ## 当前工作目录及更改

# %%
os.getcwd()
# Out:
# 'E:\\XiangGuanXueXi\\ReLearnPython\\file\\jupyter'

# %%
os.chdir('E:\\XiangGuanXueXi\\ReLearnPython\\file\\py')

# %%
os.getcwd()
# Out:
# 'E:\\XiangGuanXueXi\\ReLearnPython\\file\\py'

# %%
os.chdir('E:\\XiangGuanXueXi\\ReLearnPython\\file\\jupyter')

# %% [markdown]
# ## 处理绝对路径和相对路径

# %%
os.path.abspath('.')
# Out:
# 'E:\\XiangGuanXueXi\\ReLearnPython\\file\\jupyter'

# %%
os.path.abspath('..\py')
# Out:
# 'E:\\XiangGuanXueXi\\ReLearnPython\\file\\py'

# %%
os.path.basename('E:\\XiangGuanXueXi\\ReLearnPython\\file\\jupyter\\file.ipynb')
# Out:
# 'file.ipynb'

# %% [markdown]
# ## 查看文件大小

# %%
os.path.getsize('file.ipynb')
# Out:
# 5317

# %%
os.listdir(os.path.dirname(os.path.abspath('.')))
# Out:
# ['jupyter', 'py']

# %%
total_size=0
for file in os.listdir(r'E:\XiangGuanXueXi\ReLearnPython\basicGrammarLearn'):
    size=os.path.getsize(os.path.join(r'E:\XiangGuanXueXi\ReLearnPython\basicGrammarLearn',file))
    print(size)
    total_size+=size
total_size
# Out:
# 170
# 776
# 324
# 184
# 950
# 683
# 639
# 208
# 169
# 256
# 245
# 737
# 5341

# %% [markdown]
# ## 读文件

# %%
file1=open('1.txt',encoding='utf-8')
context=file1.read()
context
# Out:
# '十年生死两茫茫，不思量，自难忘。\n千里孤坟，无处话凄凉。纵使相逢应不识，尘满面，鬓如霜。\n夜来幽梦忽还乡，小轩窗，正梳妆。\n相顾无言，惟有泪千行。料得年年肠断处，明月夜，短松冈。'

# %%
file2=open('1.txt',encoding='utf-8')
for text in file2.readlines():
    print(text)
# Out:
# 十年生死两茫茫，不思量，自难忘。
#
# 千里孤坟，无处话凄凉。纵使相逢应不识，尘满面，鬓如霜。
#
# 夜来幽梦忽还乡，小轩窗，正梳妆。
#
# 相顾无言，惟有泪千行。料得年年肠断处，明月夜，短松冈。
