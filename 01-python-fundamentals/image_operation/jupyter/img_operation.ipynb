# %% [markdown]
# # 图像操作

# %%
from PIL import Image
test=Image.open('../img/img.png')

# %%
test.size
# Out:
# (204, 192)

# %%
test.filename
# Out:
# '../img/img.png'

# %%
test.format
# Out:
# 'PNG'

# %%
test.save('../img/test.jpg')

# %%
test.format_description
# Out:
# 'Portable network graphics'

# %%
im=Image.new('RGBA',(100,200),'chocolate')

# %%
im
# Out:
# <PIL.Image.Image image mode=RGBA size=100x200>

# %%
from PIL import ImageColor

# %%
ImageColor.getcolor('chocolate','RGBA')
# Out:
# (210, 105, 30, 255)

# %%
crop=test.crop((20,30,80,90))

# %%
crop
# Out:
# <PIL.Image.Image image mode=RGB size=60x60>

# %%
test_width,test_height=test.size
paste_width,paste_height=crop.size

# %%
for left in range(0,test_width,paste_width):
    for top in range(0,test_height,paste_height):
        print(left,top)
        test.paste(crop,(left,top))
# Out:
# 0 0
# 0 60
# 0 120
# 0 180
# 60 0
# 60 60
# 60 120
# 60 180
# 120 0
# 120 60
# 120 120
# 120 180
# 180 0
# 180 60
# 180 120
# 180 180

# %%
quarter_test=test.resize((test_width//2,test_height//2))
quarter_test
# Out:
# <PIL.Image.Image image mode=RGB size=102x96>

# %%
test.rotate(5)
# Out:
# <PIL.Image.Image image mode=RGB size=204x192>

# %%
test.rotate(5,expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=220x210>

# %%
img=Image.new('RGBA',(100,100))
img
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %%
for x in range(100):
    for y in range(50):
        img.putpixel((x,y),ImageColor.getcolor('darkgray','RGBA'))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>
